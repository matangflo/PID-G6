# %%
#⚠️Generación del csv⚠️
# No ejecutar, ya que puede tardar mucho, El .csv ya esta creado este codigo es para ver como ha sido creado
import os
import cv2
import mediapipe as mp
import numpy as np
import pandas as pd

mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=True, min_detection_confidence=0.5)

dataset_folder = "dataset"
data = []
labels = []

for pose_folder in os.listdir(dataset_folder):
    pose_path = os.path.join(dataset_folder, pose_folder)
    if os.path.isdir(pose_path):
        for img_name in os.listdir(pose_path):
            if img_name.endswith(('.jpg', '.png')):
                img_path = os.path.join(pose_path, img_name)
                image = cv2.imread(img_path)
                image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                results = pose.process(image_rgb)

                if results.pose_landmarks:
                    landmarks = []
                    for lm in results.pose_landmarks.landmark:
                        landmarks.extend([lm.x, lm.y, lm.z])

                    data.append(landmarks)
                    labels.append(pose_folder)

df = pd.DataFrame(data)
df['label'] = labels
df.to_csv("landmarks_dataset.csv", index=False)

print("Landmarks guardados en landmarks_dataset.csv")

pose.close()
# Out:
# Landmarks guardados en landmarks_dataset.csv

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import joblib

csv_file = "landmarks_dataset.csv"
df = pd.read_csv(csv_file, header=None)

# Separar características (X) y etiquetas (y)
X = df.iloc[:, :-1].values  
y = df.iloc[:, -1].values   

# Convertir etiquetas a números
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
num_classes = len(np.unique(y_encoded))

# Normalizar los datos
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Dividir datos en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_encoded, test_size=0.2, random_state=42)

# Arquitectura de la red
model = Sequential([
    BatchNormalization(input_shape=(X_train.shape[1],)),
    Dense(512, activation='relu'),
    Dropout(0.2),
    Dense(256, activation='relu'),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dense(num_classes, activation='softmax')
])

# Compilar modelo
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0005)
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Callbacks para mejorar entrenamiento
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-5)

# Entrenamiento del modelo
history = model.fit(X_train, y_train, epochs=100, batch_size=32,
                    validation_data=(X_test, y_test),
                    callbacks=[early_stop, reduce_lr])

# Evaluación el modelo
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Precisión en test: {test_acc:.2f}")

# Guardar modelo y scaler
model.save("modelo_pose_mejorado.keras")
joblib.dump(scaler, 'scaler.pkl')

# Visualizar entrenamiento
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Validación')
plt.title('Precisión')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Entrenamiento')
plt.plot(history.history['val_loss'], label='Validación')
plt.title('Pérdida')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# C:\Users\USUARIO\miniconda3\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:142: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.0369 - loss: 4.5477 - val_accuracy: 0.0594 - val_loss: 4.4696 - learning_rate: 5.0000e-04
# Epoch 2/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.1150 - loss: 3.7580 - val_accuracy: 0.1385 - val_loss: 3.9915 - learning_rate: 5.0000e-04
# Epoch 3/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.2066 - loss: 3.1030 - val_accuracy: 0.2212 - val_loss: 3.4061 - learning_rate: 5.0000e-04
# Epoch 4/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.2847 - loss: 2.6248 - val_accuracy: 0.3381 - val_loss: 2.7351 - learning_rate: 5.0000e-04
# Epoch 5/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3586 - loss: 2.3628 - val_accuracy: 0.4092 - val_loss: 2.2562 - learning_rate: 5.0000e-04
# Epoch 6/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3902 - loss: 2.1673 - val_accuracy: 0.4460 - val_loss: 2.0572 - learning_rate: 5.0000e-04
# Epoch 7/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4350 - loss: 1.9907 - val_accuracy: 0.4685 - val_loss: 1.8818 - learning_rate: 5.0000e-04
# Epoch 8/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4736 - loss: 1.8024 - val_accuracy: 0.5459 - val_loss: 1.7844 - learning_rate: 5.0000e-04
# Epoch 9/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5015 - loss: 1.7536 - val_accuracy: 0.5351 - val_loss: 1.7509 - learning_rate: 5.0000e-04
# Epoch 10/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5128 - loss: 1.6801 - val_accuracy: 0.5459 - val_loss: 1.6793 - learning_rate: 5.0000e-04
# Epoch 11/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5482 - loss: 1.5723 - val_accuracy: 0.5737 - val_loss: 1.5971 - learning_rate: 5.0000e-04
# Epoch 12/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5625 - loss: 1.5450 - val_accuracy: 0.5971 - val_loss: 1.6052 - learning_rate: 5.0000e-04
# Epoch 13/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5884 - loss: 1.4395 - val_accuracy: 0.6061 - val_loss: 1.5347 - learning_rate: 5.0000e-04
# Epoch 14/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6091 - loss: 1.3700 - val_accuracy: 0.5962 - val_loss: 1.5055 - learning_rate: 5.0000e-04
# Epoch 15/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6196 - loss: 1.3427 - val_accuracy: 0.6007 - val_loss: 1.4796 - learning_rate: 5.0000e-04
# Epoch 16/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6183 - loss: 1.2998 - val_accuracy: 0.6214 - val_loss: 1.4252 - learning_rate: 5.0000e-04
# Epoch 17/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6284 - loss: 1.2581 - val_accuracy: 0.6232 - val_loss: 1.4574 - learning_rate: 5.0000e-04
# Epoch 18/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6467 - loss: 1.2079 - val_accuracy: 0.6484 - val_loss: 1.3674 - learning_rate: 5.0000e-04
# Epoch 19/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6490 - loss: 1.1650 - val_accuracy: 0.6313 - val_loss: 1.3896 - learning_rate: 5.0000e-04
# Epoch 20/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6465 - loss: 1.1500 - val_accuracy: 0.6412 - val_loss: 1.3784 - learning_rate: 5.0000e-04
# Epoch 21/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6396 - loss: 1.1754 - val_accuracy: 0.6511 - val_loss: 1.3435 - learning_rate: 5.0000e-04
# Epoch 22/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6778 - loss: 1.0676 - val_accuracy: 0.6484 - val_loss: 1.3231 - learning_rate: 5.0000e-04
# Epoch 23/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6544 - loss: 1.0848 - val_accuracy: 0.6448 - val_loss: 1.3375 - learning_rate: 5.0000e-04
# Epoch 24/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6811 - loss: 1.0251 - val_accuracy: 0.6511 - val_loss: 1.3303 - learning_rate: 5.0000e-04
# Epoch 25/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6760 - loss: 1.0362 - val_accuracy: 0.6502 - val_loss: 1.3046 - learning_rate: 5.0000e-04
# Epoch 26/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7142 - loss: 0.9014 - val_accuracy: 0.6691 - val_loss: 1.3006 - learning_rate: 5.0000e-04
# Epoch 27/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7122 - loss: 0.9149 - val_accuracy: 0.6610 - val_loss: 1.2793 - learning_rate: 5.0000e-04
# Epoch 28/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6907 - loss: 0.9597 - val_accuracy: 0.6556 - val_loss: 1.2852 - learning_rate: 5.0000e-04
# Epoch 29/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7148 - loss: 0.8750 - val_accuracy: 0.6727 - val_loss: 1.2777 - learning_rate: 5.0000e-04
# Epoch 30/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7180 - loss: 0.8682 - val_accuracy: 0.6808 - val_loss: 1.2551 - learning_rate: 5.0000e-04
# Epoch 31/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7257 - loss: 0.8571 - val_accuracy: 0.6745 - val_loss: 1.2433 - learning_rate: 5.0000e-04
# Epoch 32/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7190 - loss: 0.8819 - val_accuracy: 0.6808 - val_loss: 1.2170 - learning_rate: 5.0000e-04
# Epoch 33/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7339 - loss: 0.8245 - val_accuracy: 0.6826 - val_loss: 1.2448 - learning_rate: 5.0000e-04
# Epoch 34/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7488 - loss: 0.7648 - val_accuracy: 0.6736 - val_loss: 1.2274 - learning_rate: 5.0000e-04
# Epoch 35/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7562 - loss: 0.7432 - val_accuracy: 0.6628 - val_loss: 1.2494 - learning_rate: 5.0000e-04
# Epoch 36/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7340 - loss: 0.8105 - val_accuracy: 0.6808 - val_loss: 1.2237 - learning_rate: 5.0000e-04
# Epoch 37/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7383 - loss: 0.7938 - val_accuracy: 0.6835 - val_loss: 1.2554 - learning_rate: 5.0000e-04
# Epoch 38/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7699 - loss: 0.7087 - val_accuracy: 0.6915 - val_loss: 1.2066 - learning_rate: 2.5000e-04
# Epoch 39/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7767 - loss: 0.6651 - val_accuracy: 0.6942 - val_loss: 1.2052 - learning_rate: 2.5000e-04
# Epoch 40/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7547 - loss: 0.7267 - val_accuracy: 0.6996 - val_loss: 1.2192 - learning_rate: 2.5000e-04
# Epoch 41/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7674 - loss: 0.6907 - val_accuracy: 0.6942 - val_loss: 1.2254 - learning_rate: 2.5000e-04
# Epoch 42/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7898 - loss: 0.6511 - val_accuracy: 0.6996 - val_loss: 1.2033 - learning_rate: 2.5000e-04
# Epoch 43/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7761 - loss: 0.6722 - val_accuracy: 0.6951 - val_loss: 1.2252 - learning_rate: 2.5000e-04
# Epoch 44/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7759 - loss: 0.6704 - val_accuracy: 0.6960 - val_loss: 1.2275 - learning_rate: 2.5000e-04
# Epoch 45/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7783 - loss: 0.6608 - val_accuracy: 0.6969 - val_loss: 1.1970 - learning_rate: 2.5000e-04
# Epoch 46/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7775 - loss: 0.6375 - val_accuracy: 0.6942 - val_loss: 1.2199 - learning_rate: 2.5000e-04
# Epoch 47/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7754 - loss: 0.6974 - val_accuracy: 0.7014 - val_loss: 1.2127 - learning_rate: 2.5000e-04
# Epoch 48/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7822 - loss: 0.6147 - val_accuracy: 0.6879 - val_loss: 1.2224 - learning_rate: 2.5000e-04
# Epoch 49/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8035 - loss: 0.6155 - val_accuracy: 0.7059 - val_loss: 1.2065 - learning_rate: 2.5000e-04
# Epoch 50/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7994 - loss: 0.5792 - val_accuracy: 0.7068 - val_loss: 1.1931 - learning_rate: 2.5000e-04
# Epoch 51/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8111 - loss: 0.5844 - val_accuracy: 0.7023 - val_loss: 1.2174 - learning_rate: 2.5000e-04
# Epoch 52/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7786 - loss: 0.6547 - val_accuracy: 0.7005 - val_loss: 1.2179 - learning_rate: 2.5000e-04
# Epoch 53/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7725 - loss: 0.6449 - val_accuracy: 0.7104 - val_loss: 1.1936 - learning_rate: 2.5000e-04
# Epoch 54/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7904 - loss: 0.6161 - val_accuracy: 0.7077 - val_loss: 1.2255 - learning_rate: 2.5000e-04
# Epoch 55/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7937 - loss: 0.5905 - val_accuracy: 0.7068 - val_loss: 1.2187 - learning_rate: 2.5000e-04
# Epoch 56/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8168 - loss: 0.5574 - val_accuracy: 0.7059 - val_loss: 1.2123 - learning_rate: 1.2500e-04
# Epoch 57/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8137 - loss: 0.5805 - val_accuracy: 0.7095 - val_loss: 1.1938 - learning_rate: 1.2500e-04
# Epoch 58/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8085 - loss: 0.5710 - val_accuracy: 0.7167 - val_loss: 1.2086 - learning_rate: 1.2500e-04
# Epoch 59/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7999 - loss: 0.6042 - val_accuracy: 0.7113 - val_loss: 1.2047 - learning_rate: 1.2500e-04
# Epoch 60/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8129 - loss: 0.5444 - val_accuracy: 0.7104 - val_loss: 1.2075 - learning_rate: 1.2500e-04
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7180 - loss: 1.2402
# Precisión en test: 0.71

# %%
import os
import cv2
import mediapipe as mp
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
import joblib

model = tf.keras.models.load_model("modelo_pose_mejorado.h5")
scaler = joblib.load('scaler.pkl')

# Carpeta con los nombres de las poses (etiquetas)
dataset_folder = "dataset"
pose_names = os.listdir(dataset_folder)

# Inicializar MediaPipe Pose
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=True, min_detection_confidence=0.5)

# Ruta de la imagen
img_path = "fotos/fotoej2.jfif"
image = cv2.imread(img_path)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Procesar la imagen con MediaPipe
results = pose.process(image_rgb)

if results.pose_landmarks:
    # Extraer los landmarks
    landmarks = []
    for lm in results.pose_landmarks.landmark:
        landmarks.extend([lm.x, lm.y, lm.z])

    # Normalizar los landmarks (escalar la entrada)
    landmarks_scaled = scaler.transform([landmarks])  # Normaliza como una fila (1, 99)
    
    # Predecir con el modelo
    predictions = model.predict(landmarks_scaled)
    
    # Obtener la clase predicha
    predicted_class = np.argmax(predictions, axis=1)

    # Obtener el nombre de la pose predicha
    predicted_pose = pose_names[predicted_class[0]]
    print(f"Predicción de la pose: {predicted_pose}")
else:
    print("No se detectaron landmarks en la imagen.")

pose.close()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [1], in <cell line: 6>()
#       4 import numpy as np
#       5 import tensorflow as tf
# ----> 6 from tensorflow.keras.models import Sequential
#       7 from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
#       8 import joblib
#
# File ~\miniconda3\lib\site-packages\keras\_tf_keras\keras\__init__.py:7, in <module>
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras.api import activations
#       8 from keras.api import applications
#       9 from keras.api import callbacks
#
# File ~\miniconda3\lib\site-packages\keras\__init__.py:2, in <module>
#       1 # DO NOT EDIT. Generated by api_gen.sh
# ----> 2 from keras.api import DTypePolicy
#       3 from keras.api import FloatDTypePolicy
#       4 from keras.api import Function
#
# File ~\miniconda3\lib\site-packages\keras\api\__init__.py:31, in <module>
#      29 from keras.api import random
#      30 from keras.api import regularizers
# ---> 31 from keras.api import saving
#      32 from keras.api import tree
#      33 from keras.api import utils
#
# File ~\miniconda3\lib\site-packages\keras\api\saving\__init__.py:7, in <module>
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras.src.saving.file_editor import KerasFileEditor
#       8 from keras.src.saving.object_registration import CustomObjectScope
#       9 from keras.src.saving.object_registration import (
#      10     CustomObjectScope as custom_object_scope,
#      11 )
#
# File ~\miniconda3\lib\site-packages\keras\src\saving\file_editor.py:6, in <module>
#       3 import pprint
#       4 import zipfile
# ----> 6 import h5py
#       7 import numpy as np
#       8 import rich.console
#
# File ~\miniconda3\lib\site-packages\h5py\__init__.py:33, in <module>
#      30     else:
#      31         raise
# ---> 33 from . import version
#      35 if version.hdf5_version_tuple != version.hdf5_built_version_tuple:
#      36     _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
#      37            "this may cause problems").format(
#      38             '{0}.{1}.{2}'.format(*version.hdf5_version_tuple),
#      39             '{0}.{1}.{2}'.format(*version.hdf5_built_version_tuple)
#      40     ))
#
# File ~\miniconda3\lib\site-packages\h5py\version.py:15, in <module>
#      10 """
#      11     Versioning module for h5py.
#      12 """
#      14 from collections import namedtuple
# ---> 15 from . import h5 as _h5
#      16 import sys
#      17 import numpy
#
# File h5py\\h5.pyx:1, in init h5py.h5()
#
# ImportError: DLL load failed while importing defs: No se encontró el proceso especificado.

# %%
import h5py
print("h5py version:", h5py.__version__)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 import h5py
#       2 print("h5py version:", h5py.__version__)
#
# File ~\miniconda3\lib\site-packages\h5py\__init__.py:33, in <module>
#      30     else:
#      31         raise
# ---> 33 from . import version
#      35 if version.hdf5_version_tuple != version.hdf5_built_version_tuple:
#      36     _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
#      37            "this may cause problems").format(
#      38             '{0}.{1}.{2}'.format(*version.hdf5_version_tuple),
#      39             '{0}.{1}.{2}'.format(*version.hdf5_built_version_tuple)
#      40     ))
#
# File ~\miniconda3\lib\site-packages\h5py\version.py:15, in <module>
#      10 """
#      11     Versioning module for h5py.
#      12 """
#      14 from collections import namedtuple
# ---> 15 from . import h5 as _h5
#      16 import sys
#      17 import numpy
#
# File h5py\\h5.pyx:1, in init h5py.h5()
#
# ImportError: DLL load failed while importing defs: No se encontró el proceso especificado.
